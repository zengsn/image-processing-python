# %% [markdown]
# ##
#
# <a name="sec00">&nbsp;</a>
#
# # <span style="font-size=24px;">Basic Image Processing in Python</span>
# > **Shaoning Zeng**, Ph.D student (yb77477@um.edu.mo).
# > Supervised by Assistant Prof. **Bob Zhang** (bobzhang@um.edu.mo).
# > *Dept. of Computer & Information Science, Faculty of Science & Technology, University of Macau.*
#
#
# ##
#
# ## Code of this lab
#
# ### https://github.com/zengsn/image-processing-python
#
# >
# > The helpers will assist you through the lab.
# >
# >
# >
#
# ##
#
# [Top](#sec00)  |  [Next: Content](#sec01)
#
# ##
#
# ##
#
# ##
#
# ##
#
# ##
#
#
# <a name="sec01">&nbsp;</a>
#
# ## Content
# [Top](#sec00)
#
# ### 1. What is a **Digital Image** ?
# ### 2. Basic Operations (基本操作): **Read, Write** and **Show** images.
# ### 3. Transformation (图像变形): **Crop, Rotate**, and **Resize** images.
# ### 4. Conversion (图像格式转换): From **RGB** (or **Color**) to **Grayscale** images.
# ### 5. Binarization (二值化): **Black-and-white** images.
# ### 6. Common Filtering (滤镜): **Smooth, Sharpen, Edge Enhancement**, etc.
# ### 7. Advanced Filtering: i.e., **Denoise**.
# ### 8. Histogram (直方图).
#
# ##
#
# [Top](#sec00)  |  [Next: 1. Digital Image](#sec02)
#
# ##
#
# ##
#
# ##
#
# ##
#
# ##
#
# <a name="sec02">&nbsp;</a>
#
# ## 1. Digital Image (数字图像)
# [Top](#sec00) | [Previous: Content](#sec01) |  [Next: 2. Basic Operations](#sec03)
#
# - A digital image is a **numeric representation**, normally **binary**, of a two-dimensional image.
# - Depending on whether the image resolution is fixed, it may be of vector or raster type.
# - By itself, the term "digital image" usually refers to **raster images** or **bitmapped images** (as opposed to vector images).
# - Common image formats: **PPM, PNG, JPEG, GIF, TIFF**, and **BMP**.
#
# ### Gray image
#
# - For monochrome (gray) images, the brightness of **each pixel** is expressed by a **numerical value**.
# - Usually in the range of **0 to 255**, **0 for black**, **255 for white**, and other values for gray between black and white.
#
# ### Color image
#
# - Color images can be represented by **two-dimensional matrices** of **Red**, **Green** and **Blue** triples.
#   - Did you hear about **RGB** ?
# - Normally, each value of a triple is between 0 and 255,
#   - 0 means that the corresponding primary color is not present in the pixel,
#   - and 255 means that the corresponding primary color is maximized in the pixel.
#
# [Example Digit Image](#sec02.1)
#
# ##
#
# ##
#
# ##
#
# ##
#
# ##
#
# <a name="sec02.1">&nbsp;</a>
#
# ### Example Digit Image: **lady_gray.jpg**
# [Top](#sec00) | [Back to: 1. Digital Image](#sec02)  |  [Next: 2. Basic Operations](#sec03)
#
# ![](https://raw.githubusercontent.com/zengsn/image-processing-python/master/pixel.png)

# %%
# 
from PIL import Image  
from numpy  import *
import matplotlib.pyplot as plt

# The image filename is lady_gray.jpg

img=Image.open('./lady_gray.jpg')

# 
plt.imshow(img)
plt.show()

# 
img.size
# Out:
# (672, 545)

# %% [markdown]
# ##
#
# ##
#
# ##
#
# ##
#
# ##
#
# ##
#
# ##
#
# <a name="sec03">&nbsp;</a>
#
# ## 2. Basic Operations
# [Top](#sec00) | [Previous: 1. Digit Image](#sec02) |  [Next: 3. Transformation](#sec04)
#
# ### Tool: Python-Pillow
#
# **Python Imaging Library** (abb. **PIL**) (in newer version known as Pillow) is a free library for the Python programming language that adds support for opening, manipulating, and saving many different image file formats.
#
# ### Read (Open) and Show an image
# There are two general ways to display am image,
# - The first method is using **im.show()** function in Pillow,
#   - however sometimes it may not work well in jupyter.
# - The alternative method is using a third party library called **matplotlib** to display it.
#
# [Example Code: Open and show an image.](#sec03.1)
#
# [Example Code: Save an image.](#sec03.2)
#
# ##
#
# ##
#
# ##
#
# ##
#
# ##
#
# <a name="sec03.1">&nbsp;</a>
#
# ### Example Code: Open and show an image.
# [Top](#sec00) | [Back to: 2. Basic Operations](#sec03)  |  [Next: 3. Transformation](#sec04)

# %%
## Example: Open and display an image. ##

from PIL import Image  
import matplotlib.pyplot as plt
img=Image.open('./street-sign.jpg')

# %matplotlib inline  
# Tip: 用这条命令防止Jupyter返回内存地址，直接显示图片

plt.imshow(img)
plt.show()

# The result will be showed below.

# %% [markdown]
# [Example Code: Save an image.](#sec03.2)
#
# ##
#
# ##
#
# ##
#
# ##
#
# ##
#
# <a name="sec03.2">&nbsp;</a>
#
# ### Example Code: Save an image.
# [Top](#sec00) | [Back to: 2. Basic Operations](#sec03)  |  [Next: 3. Transformation](#sec04)

# %%
## Save an image. ##

## Source name: street-sign.jpg
img=Image.open('./street-sign.jpg')

## New name: street-sign-save.jpg
img.save('street-sign-save.jpg')

## Tip: 
## When you finish these steps, you will find a new file called street-sign-save.jpg in your left column.

## Or, we can open it now.
img=Image.open('./street-sign-save.jpg')
plt.imshow(img)
plt.show()

# The result will be showed below.

# %% [markdown]
# Tip: Compare to [Example Code: Open and show an image. ](#sec03.1)
#
# ##
#
# ##
#
# ##
#
# ##
#
# ##
#
# <a name="sec04">&nbsp;</a>
#
# ## 3. Transformation
# [Top](#sec00) | [Previous: 2. Basic Operations](#sec03)  |  [Next: 4. Conversion](#sec05)
#
# This part will tell you basic image transforms such as **Crop, Rotate, Resize** an image, etc.
#
# ### Crop an image
#
# If your image is too big or some parts of the image is useful, you can crop it.
#
# Here is an example.

# %%
## 
from PIL import Image  
import matplotlib.pyplot as plt

## 
img=Image.open('./street-sign.jpg')

## 
region = (100,100,700,450)
cropImg = img.crop(region)

## 
plt.imshow(cropImg)
plt.show()

# The result will be showed below.

# %% [markdown]
# ### Rotate an image
#
# If some images are not angeled properly, you may need to rotate them to make them look better.
#
# Here is an example.

# %%
## 
img_rotate = img.rotate(45)  

## Tip: You can change the number of rotate angle in this function.

##
plt.imshow(img_rotate)
plt.show()

# The result will be showed below.

# %%
## ROTATE_90 means rotate 90 degree
img_rotate = img.transpose(Image.ROTATE_90) 

##  
plt.imshow(img_rotate)
plt.show()

# The result will be showed below.

# %% [markdown]
# ### Resize an image
# Sometime images are too large to process or need to cost lots of time to process, you can resize images to make them more smaller.
#
# Here is an example.

# %%
## Scale the image to 300*400 pixel size
img_resize = img.resize((400, 300)) 

## 
plt.imshow(img_resize)
plt.show()

# The result will be showed below.

# %% [markdown]
# [Back to: 3. Transformation](#sec04)
#
# ##
#
# ##
#
# ##
#
# <a name="sec05">&nbsp;</a>
#
# ## 4. Conversion
# [Top](#sec00) | [Previous: 3. Transformation](#sec04)  |  [Next: 5. Binarization ](#sec06)
#
# Pillow has its own **conversion()** method to convert images into different formats.
#
# Take gray scale image conversion as an example:

# %%
## Open and show an image, once again. ##
from PIL import Image  
import matplotlib.pyplot as plt
img=Image.open('./street-sign.jpg')

## Convert it to a grayscale image:  
## L means grapscale mode，you can try RGB, F mode;
img_convert = img.convert('L') 

## Tip: If having error in this line, you may need upgrade matplotlib like this: 
## pip install matplotlib --upgrade

## 
plt.imshow(img_convert)
plt.show()

# The result will be showed below.

# %% [markdown]
# ##
#
# ##
#
# ##
#
# <a name="sec06">&nbsp;</a>
#
# ## 5. Binarization
# [Top](#sec00) | [Previous: 4. Conversion](#sec05)  |  [Next: 6. Common Filtering ](#sec07)
#
# - Image binarization is the process of setting the gray value of the pixels on the image to **0 or 255**,
#   - that is to say, the whole image presents an obvious **black-and-white** effect.
#
# - In digital image processing, binary image plays a very important role.
#   - The binarization of an image greatly **reduces the amount of data** in the image, so that the outline of the object can be highlighted.
#
# - In Pillow, we use **point()** method to judge each pixel of an image, and set its gray value to 0 or 255 according to its relative size with the mean value, before converting it into a binary image.

# %%
WHITE, BLACK = 255, 0   # define gray constant value

img_point = img.point(lambda x: WHITE if x > 128 else BLACK)  # judge each pixel

img_binary = img_point.convert('1')  # convert to binary image

## 
plt.imshow(img_binary)
plt.show()

# The result will be showed below.

# %% [markdown]
# ##
#
# ##
#
# ##
#
# <a name="sec07">&nbsp;</a>
#
# ## 6. Common Filtering
# [Top](#sec00) | [Previous: 5. Binarization](#sec06)  |  [Next: 7. Advanced Filtering ](#sec08)
#
# - Image filtering in Python mainly deals with image **Smoothing, Sharpening** and **Edge enhancement**.
#   - You can regard it as a filter in a mobile photo processing app, like *美图秀秀*.
#
# - There are many kinds of filtering in Pillow, like **Relief Filtering**.

# %%
## 
from PIL import Image,ImageFilter  

## EMBOSS means filter type we used.
img_filter = img.filter(ImageFilter.EMBOSS) 

## TODO: you can choose anther method based on your work.

## 
plt.imshow(img_filter)
plt.show()

# The result will be showed below.

# %% [markdown]
# We can now change to other filters such as EDGE_ENHANCE to find the egdes of objects in the image.

# %%
##
from PIL import Image,ImageFilter  

## EDGE_ENHANCE filter, to find traffic sign edge better.
img_filter = img.filter(ImageFilter.EDGE_ENHANCE) 

## 
plt.imshow(img_filter)
plt.show()

# The result will be showed below.

# %% [markdown]
# We can now change to other filters such as CONTOUR to find the contours of objects in the image.

# %%
##
from PIL import Image,ImageFilter  

## CONTOUR filter, to find traffic sign contour.
img_filter = img.filter(ImageFilter.CONTOUR)  

## 
plt.imshow(img_filter)
plt.show()

# The result will be showed below.

# %% [markdown]
# [Back to: 6. Common Filtering](#sec07)
#
# ##
#
# ##
#
# ##
#
# <a name="sec08">&nbsp;</a>
#
# ## 7. Advanced Filtering: Image Denosing
# [Top](#sec00) | [Previous: 6. Common Filtering](#sec07)  |  [Next: 8. Histogram](#sec09)
#
# Some images have some noise which makes it difficult to evaluate, we can use some filters to remove these noise.
#
# Here we give an example using **Median Filter** to remove noise in the image.
#
# - The Median Filter is a nonlinear digital filtering technique, often used to remove noise from an image or signal.
# - Such noise reduction is a typical **pre-processing** step to improve the results for later processing (for example, edge detection on an image).
# - Median filtering is widely used in digital image processing because under certain conditions it **preserves edges while removing noise** (see discussion below), also having applications in signal processing.
#
# *Note: This image is "street-sign_noise.jpg", not "street-sign.jpg".*

# %%
### read a image then display it###
from PIL import Image  
import matplotlib.pyplot as plt

## Open the image
img_noise=Image.open('./street-sign_noise.jpg')

## 
plt.figure()
plt.subplot(1,2,1)
plt.imshow(img_noise)
plt.subplot(1,2,2)

## MedianFilter, to remove noise
img_filter = img_noise.filter(ImageFilter.MedianFilter(5)) 

## 
plt.imshow(img_filter)
plt.show()

# The result will be showed below.

# %% [markdown]
# You can try other filters to remove noise such as a Gaussian filter, and also try to change different parameters in "img_noise.filter(ImageFilter.GaussianBlur(radius=2))" and check its results.
#
# Try to undertand its principle and corresponding results.

# %%
### read a image then display it###
from PIL import Image  
import matplotlib.pyplot as plt

## Open the image
img_noise=Image.open('./street-sign_noise.jpg')

##
plt.figure()
plt.subplot(1,2,1)
plt.imshow(img_noise)
plt.subplot(1,2,2)

## GaussianBlur, to to remove noise.
img_filter = img_noise.filter(ImageFilter.GaussianBlur(radius=2)) 

##
plt.imshow(img_filter)
plt.show()

# The result will be showed below.

# %% [markdown]
# ##
#
# ##
#
# ##
#
# <a name="sec09">&nbsp;</a>
#
# ## 8. Histogram (直方图)
# [Top](#sec00) | [Previous: 7. Advanced Filtering](#sec08)
#
# An image histogram is a type of histogram that acts as **a graphical representation of the tonal distribution in a digital image**. It plots the number of pixels for each tonal value. By looking at the histogram for a specific image a viewer will be able to judge the entire tonal distribution at a glance
#
# 1. Histogram is a graphical representation of the intensity distribution of an image.
# 2. Histogram quantifies the number of pixels for each intensity value.
#
# Here is an example of the histogram for color images.

# %%
## 
from PIL import Image  
import matplotlib.pyplot as plt

## Use OpenCV here
import cv2 
img = cv2.imread('./street-sign.jpg')

## Tip: pip install opencv-python

## Convert RGB color image to gray scale image
img = cv2.cvtColor (img, cv2.COLOR_BGR2GRAY) 

## 
plt.figure()
plt.subplot(1,2,1)
plt.imshow(img,cmap=plt.cm.gray )
plt.subplot(1,2,2)

## Histogram
plt.hist(img.ravel(),256,[0,256])

# The result will be showed below.
# Out:
# (array([2.000e+00, 5.000e+00, 7.000e+00, 3.000e+00, 2.200e+01, 2.600e+01,
#         4.500e+01, 6.100e+01, 1.350e+02, 1.900e+02, 2.700e+02, 3.350e+02,
#         4.470e+02, 5.710e+02, 6.280e+02, 7.010e+02, 7.800e+02, 9.010e+02,
#         1.027e+03, 1.144e+03, 1.268e+03, 1.379e+03, 1.506e+03, 1.646e+03,
#         1.697e+03, 1.905e+03, 2.127e+03, 2.162e+03, 2.261e+03, 2.582e+03,
#         2.748e+03, 2.783e+03, 2.898e+03, 2.981e+03, 3.090e+03, 3.190e+03,
#         3.150e+03, 3.137e+03, 3.150e+03, 3.222e+03, 3.308e+03, 3.380e+03,
#         3.423e+03, 3.375e+03, 3.279e+03, 3.357e+03, 3.339e+03, 3.366e+03,
#         3.284e+03, 3.257e+03, 3.239e+03, 3.254e+03, 3.172e+03, 3.186e+03,
#         3.192e+03, 2.996e+03, 2.876e+03, 2.803e+03, 2.531e+03, 2.509e+03,
#         2.331e+03, 2.430e+03, 2.309e+03, 2.154e+03, 2.168e+03, 2.077e+03,
#         2.026e+03, 1.917e+03, 1.920e+03, 1.787e+03, 1.770e+03, 1.698e+03,
#         1.574e+03, 1.689e+03, 1.648e+03, 1.628e+03, 1.583e+03, 1.538e+03,
# ...

# %% [markdown]
# ##
#
# ## Code of this lab
#
# ### https://github.com/zengsn/image-processing-python
#
# >
# > The helpers will assist you through the lab.
# >
# >
# >
#
# [Top](#sec00)
